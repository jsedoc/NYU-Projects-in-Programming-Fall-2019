# %% [markdown]
# # All material ©2019, Alex Siegman

# %% [markdown]
# ---

# %% [markdown]
# ## Welcome to Projects in Programming & Data Science. We're going to jump right in to the mix.
#
# ### Today we are going to leverage the CitiBike API to populate a MySQL database at regular intervals. Consider this your warm-up for the semester.

# %% [markdown]
# ---

# %% [markdown]
# ## MySQL Setup
# #### (https://www.mysql.com/about/)

# %% [markdown]
# **To install MySQL, in your terminal:**
#
# 1. \> brew install mysql
# 2. \> unset TMPDIR
# 3. \> mysql_secure_installation
# 4. \> {enter your preferred password}
# 5. \> {skip all options presented}
#
# **To run MySQL, in your terminal:**
#
# 1. \> mysql -u root -p
# 2. \> {enter password}
# 3. \> quit
#
# **To set MySQL privileges:**
#
# 1. \> mysql -u root -p
# 2. \> {enter password}
# 3. \> grant all privileges on *.* to 'username'@'localhost' identified by 'password'
#
# > _to change your password, use mysql> alter user 'user'@'localhost' identified by 'newpassword'_
#
# 4. \> flush privileges
# 5. \> quit
#
# **To create a MySQL database:**
#
# 1. mysql> create database citibike

# %% [markdown]
# ## Now, let's check out the API we'll be working with:
#
# ### https://streamdata.io/developers/api-gallery/new-york-citibike-api/

# %%
# first, let's request the json from the CitiBike API URL

import time 
import json 
import urllib.request

with urllib.request.urlopen("https://gbfs.citibikenyc.com/gbfs/en/station_status.json") as url:
    data = json.loads(url.read().decode())
    print(data)
# Out:
# {'last_updated': 1565108291, 'ttl': 10, 'data': {'stations': [{'station_id': '168', 'num_bikes_available': 35, 'num_ebikes_available': 0, 'num_bikes_disabled': 1, 'num_docks_available': 11, 'num_docks_disabled': 0, 'is_installed': 1, 'is_renting': 1, 'is_returning': 0, 'last_reported': 1565108198, 'eightd_has_available_keys': False, 'eightd_active_station_services': [{'id': 'bedaaf2b-8664-469e-8681-26ff8059765b'}]}, {'station_id': '281', 'num_bikes_available': 7, 'num_ebikes_available': 0, 'num_bikes_disabled': 6, 'num_docks_available': 53, 'num_docks_disabled': 0, 'is_installed': 1, 'is_renting': 1, 'is_returning': 0, 'last_reported': 1565108289, 'eightd_has_available_keys': True, 'eightd_active_station_services': [{'id': '32461582-cd1e-4ecf-a5ea-563593fa7009'}]}, {'station_id': '304', 'num_bikes_available': 6, 'num_ebikes_available': 0, 'num_bikes_disabled': 0, 'num_docks_available': 27, 'num_docks_disabled': 0, 'is_installed': 1, 'is_renting': 1, 'is_returning': 0, 'last_reported': 1565108038, 'eightd_has_available_keys': False, 'eightd_active_station_services': [{'id': 'a58d9e34-2f28-40eb-b4a6-c8c01375657a'}]}, {'station_id': '337', 'num_bikes_available': 4, 'num_ebikes_available': 0, 'num_bikes_disabled': 1, 'num_docks_available': 32, 'num_docks_disabled': 0, 'is_installed': 1, 'is_renting': 1, 'is_returning': 0, 'last_reported': 1565108241, 'eightd_has_available_keys': False, 'eightd_active_station_services': [{'id': '8ec29d39-9642-466a-9a20-aad1e5c4788a'}]}, {'station_id': '347', 'num_bikes_available': 12, 'num_ebikes_available': 0, 'num_bikes_disabled': 0, 'num_docks_available': 23, 'num_docks_disabled': 0, 'is_installed': 1, 'is_renting': 1, 'is_returning': 0, 'last_reported': 1565108065, 'eightd_has_available_keys': False, 'eightd_active_station_services': [{'id': '6a00be67-3935-4ada-a20d-8007831afb85'}]}, {'station_id': '359', 'num_bikes_available': 9, 'num_ebikes_available': 0, 'num_bikes_disabled': 2, 'num_docks_available': 53, 'num_docks_disabled': 0, 'is_installed': 1, 'is_renting': 1, 'is_returning': 0, 'last_reported': 1565107973, 'eightd_has_available_keys': False, 'eightd_active_station_services': [{'id': '2e104e31-606a-44af-8b25-ceaffc338489'}]}, {'station_id': '377', 'num_bikes_available': 11, 'num_ebikes_available': 0, 'num_bikes_disabled': 0, 'num_docks_available': 36, 'num_docks_disabled': 0, 'is_installed': 1, 'is_renting': 1, 'is_returning': 1, 'last_reported': 1565108183, 'eightd_has_available_keys': False, 'eightd_active_station_services': [{'id': '82b94401-0c20-45f5-b007-86ae46bec976'}]}, {'station_id': '388', 'num_bikes_available': 1, 'num_ebikes_available': 0, 'num_bikes_disabled': 2, 'num_docks_available': 32, 'num_docks_disabled': 0, 'is_installed': 1, 'is_renting': 1, 'is_returning': 0, 'last_reported': 1565108288, 'eightd_has_available_keys': False, 'eightd_active_station_services': [{'id': '0321c05b-54f8-44d5-949c-df912aa1e5a4'}]}, {'station_id': '402', 'num_bikes_available': 9, 'num_ebikes_available': 0, 'num_bikes_disabled': 1, 'num_docks_available': 29, 'num_docks_disabled': 0, 'is_installed': 1, 'is_renting': 1, 'is_returning': 0, 'last_reported': 1565107841, 'eightd_has_available_keys': False, 'eightd_active_station_services': [{'id': '37a1ae1b-3dd6-4876-8c57-572aaac97981'}]}, {'station_id': '426', 'num_bikes_available': 1, 'num_ebikes_available': 0, 'num_bikes_disabled': 0, 'num_docks_available': 28, 'num_docks_disabled': 0, 'is_installed': 1, 'is_renting': 1, 'is_returning': 0, 'last_reported': 1565108159, 'eightd_has_available_keys': True, 'eightd_active_station_services': [{'id': '1e5ac43a-f79b-4184-a026-7e4505a750c4'}]}, {'station_id': '456', 'num_bikes_available': 4, 'num_ebikes_available': 0, 'num_bikes_disabled': 3, 'num_docks_available': 28, 'num_docks_disabled': 0, 'is_installed': 1, 'is_renting': 1, 'is_returning': 0, 'last_reported': 1565108047, 'eightd_has_available_keys': False, 'eightd_active_station_services': [{'id': '85123018-9fad-4146-997b-cf7f51f27428'}]}, {'station_ ...

# %%
stations = data['data']['stations'] # iterate through the json to find the station data

# %%
import pandas as pd # we'll use pandas just to visualize our data

df_stations = pd.DataFrame(stations)
df_stations.head() # check the first five station entries
# Out:
#                      eightd_active_station_services  \
# 0  [{'id': 'bedaaf2b-8664-469e-8681-26ff8059765b'}]
# 1  [{'id': '32461582-cd1e-4ecf-a5ea-563593fa7009'}]
# 2  [{'id': 'a58d9e34-2f28-40eb-b4a6-c8c01375657a'}]
# 3  [{'id': '8ec29d39-9642-466a-9a20-aad1e5c4788a'}]
# 4  [{'id': '6a00be67-3935-4ada-a20d-8007831afb85'}]
#
#    eightd_has_available_keys  is_installed  is_renting  is_returning  \
# 0                      False             1           1             0
# 1                       True             1           1             0
# 2                      False             1           1             0
# 3                      False             1           1             0
# 4                      False             1           1             0
#
#    last_reported  num_bikes_available  num_bikes_disabled  \
# 0     1565108198                   35                   1
# 1     1565108289                    7                   6
# 2     1565108038                    6                   0
# 3     1565108241                    4                   1
# 4     1565108065                   12                   0
#
#    num_docks_available  num_docks_disabled  num_ebikes_available station_id
# 0                   11                   0                     0        168
# 1                   53                   0                     0        281
# 2                   27                   0                     0        304
# 3                   32                   0                     0        337
# 4                   23                   0                     0        347

# %%
import MySQLdb 

# MySQLdb is a way to interface with a MySQL database via a Python API 
# http://mysql-python.sourceforge.net/MySQLdb.html

# %%
db = MySQLdb.connect(passwd="password",db="citibike") # connect to our db

# %%
c = db.cursor() # set our cursor

# %%
# create our table

c.execute("CREATE TABLE IF NOT EXISTS StationInfo (station_id int, num_ebikes_available int, num_docks_disabled int, num_docks_available int, num_bikes_disabled int, num_bikes_available int, last_reported varchar(250), is_returning int, is_renting int, is_installed int, eightd_has_available_keys bool);")

c.close()
db.commit()

# %%
from datetime import datetime # import the datetime library 

c = db.cursor() # set our cursor 

# below, we are going to populate our table using "INSERT IGNORE INTO"
# this allows us to avoid errors when we periodically update our database 

query_template = """INSERT IGNORE INTO StationInfo(station_id, num_ebikes_available, num_docks_disabled, \
num_docks_available, num_bikes_disabled, num_bikes_available, last_reported, is_returning, is_renting, \
is_installed, eightd_has_available_keys) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);"""

for entry in stations: # for every station entry in the json 
    station_id = int(entry['station_id']) # find and set station_id
    num_ebikes_available = int(entry['num_ebikes_available']) # find and set num_ebikes_available
    num_docks_disabled = int(entry['num_docks_disabled']) # find and set num_docks_disabled
    num_docks_available = int(entry['num_docks_available']) # find and set num_docks_available
    num_bikes_disabled = int(entry['num_bikes_disabled']) # find and set num_bikes_disabled
    num_bikes_available = int(entry['num_bikes_available']) # find and set num_bikes_available
    last_reported = str(entry['last_reported']) # find and set last_reported
    is_returning = int(entry['is_returning']) # find and set is_returning
    is_renting = int(entry['is_renting']) # find and set is_renting
    is_installed = int(entry['is_installed']) # find and set is_installed
    eightd_has_available_keys = bool(entry['eightd_has_available_keys']) # find and set eightd_has_available_keys
                           
    print("Inserting Station:", station_id, num_ebikes_available, num_docks_disabled, num_docks_available, num_bikes_disabled, num_bikes_available, last_reported, is_returning, is_renting, is_installed, eightd_has_available_keys) 
    query_parameters = (station_id, num_ebikes_available, num_docks_disabled, num_docks_available, num_bikes_disabled, num_bikes_available, last_reported, is_returning, is_renting, is_installed, eightd_has_available_keys) 
   
    c.execute(query_template, query_parameters) # execute insert query and parameters

c.close()
db.commit()
# Out:
# Inserting Station: 168 0 0 11 1 35 1565108198 0 1 1 False
# Inserting Station: 281 0 0 53 6 7 1565108289 0 1 1 True
# Inserting Station: 304 0 0 27 0 6 1565108038 0 1 1 False
# Inserting Station: 337 0 0 32 1 4 1565108241 0 1 1 False
# Inserting Station: 347 0 0 23 0 12 1565108065 0 1 1 False
# Inserting Station: 3546 0 0 20 0 1 1565107000 1 1 1 False
# Inserting Station: 3547 0 1 8 2 30 1565107942 1 1 1 False
# Inserting Station: 3549 0 0 25 0 0 1565102600 1 1 1 False
# Inserting Station: 3551 0 0 5 0 18 1565107862 1 1 1 False
# Inserting Station: 3552 0 0 32 0 0 1565108173 1 1 1 False
# Inserting Station: 3553 0 0 15 0 2 1565105856 1 1 1 False
# Inserting Station: 3554 0 0 8 0 19 1565107212 1 1 1 False
# Inserting Station: 3555 0 0 9 2 12 1565107774 1 1 1 False
# Inserting Station: 3556 0 0 15 1 3 1565106682 1 1 1 False
# Inserting Station: 3557 0 0 0 0 19 1565103876 1 1 1 False
# Inserting Station: 3558 0 0 27 0 0 1565106852 1 1 1 False
# Inserting Station: 3559 0 0 12 1 6 1565107313 1 1 1 False
# Inserting Station: 3560 0 0 11 0 8 1565107768 1 1 1 False
# Inserting Station: 3561 0 0 13 0 11 1565104711 1 1 1 False
# Inserting Station: 3562 0 0 26 0 1 1565108018 1 1 1 False
# Inserting Station: 3563 0 0 25 0 4 1565107455 1 1 1 False
# Inserting Station: 3564 0 0 2 0 16 1565104473 1 1 1 False
# Inserting Station: 3565 0 0 9 0 10 1565108126 1 1 1 False
# Inserting Station: 3566 0 0 20 0 5 1565105676 1 1 1 False
# Inserting Station: 3567 0 0 12 0 7 1565066221 1 1 1 False
# Inserting Station: 3568 0 0 6 0 15 1565108103 1 1 1 False
# Inserting Station: 3569 0 0 29 0 0 1565108029 1 1 1 False
# Inserting Station: 3570 0 0 20 0 11 1565106071 1 1 1 False
# Inserting Station: 3571 0 0 21 1 2 1565105676 1 1 1 False
# Inserting Station: 3572 0 0 16 0 17 1565108075 1 1 1 False
# Inserting Station: 3573 0 0 11 0 3 1565100507 1 1 1 False
# Inserting Station: 3574 0 0 23 0 0 1565107693 1 1 1 False
# Inserting Station: 3575 0 0 11 0 8 1565106420 1 1 1 False
# Inserting Station: 3576 0 0 26 1 0 1565107623 1 1 1 False
# Inserting Station: 3577 0 0 6 0 17 1565105414 1 1 1 False
# Inserting Station: 3578 0 0 18 0 3 1565105747 1 1 1 False
# Inserting Station: 3579 0 0 19 0 6 1565106797 1 1 1 False
# Inserting Station: 3580 0 0 28 1 1 1565107045 1 1 1 False
# Inserting Station: 3581 0 0 27 0 0 1565104790 1 1 1 False
# Inserting Station: 3582 0 0 20 0 0 1565097648 1 1 1 False
# Inserting Station: 3583 0 0 31 0 0 1565107385 1 1 1 False
# Inserting Station: 3584 0 0 37 0 5 1565108227 1 1 1 False
# Inserting Station: 3585 0 0 21 0 3 1565108254 1 1 1 False
# Inserting Station: 3586 0 0 5 0 14 1565097852 1 1 1 False
# Inserting Station: 3587 0 0 27 0 0 1565106885 1 1 1 False
# Inserting Station: 3588 0 0 1 0 20 1565106693 1 1 1 False
# Inserting Station: 3589 0 0 1 0 9 1565107334 1 1 1 False
# Inserting Station: 3590 0 0 17 0 2 1565107953 1 1 1 False
# Inserting Station: 3733 0 0 41 2 3 1565108068 1 1 1 False
# Inserting Station: 3734 0 0 42 1 7 1565108259 1 1 1 False
# Inserting Station: 3737 0 0 34 1 0 1565106931 1 1 1 False
# Inserting Station: 3745 0 0 12 1 14 1565106131 1 1 1 False
# Inserting Station: 3746 0 0 6 1 41 1565108156 1 1 1 False
# Inserting Station: 3747 0 0 31 1 1 1565107506 1 1 1 False
# Inserting Station: 3749 0 0 19 2 2 1565108095 1 1 1 False
# Inserting Station: 3755 0 0 19 0 0 1565107579 1 1 1 False
# Inserting Station: 3756 0 0 10 0 11 1565108283 1 1 1 False
# Inserting Station: 3757 0 0 13 0 10 1565104105 1 1 1 False
# Inserting Station: 3758 0 0 7 1 11 1565096483 1 1 1 False
# Inserting Station: 3759 0 0 16 0 3 1565107853 1 1 1 False
# Inserting Station: 3760 0 0 22 0 1 1565099904 1 1 1 False
# Inserting Station: 3761 0 0 24 0 3 1565107366 1 1 1 False
# Inserting Station: 3762 0 0 2 0 25 1565104744 1 1 1 False
# Inserting Station: 3763 0 0 19 0 8 1565106738 1 1 1 False
# Inserting Station: 3764 0 0 5 0 16 1565108230 1 1 1 False
# Inserting Station: 3765 0 0 19 1 1 1565107887 1 1 1 False
# Inserting Station: 3766 0 0 24 0 0 1565106162 1 1 1 False
# Inserting Station: 3767 0 0 18 0 1 1565098616 1 1 1 False
# Inserting Station: 3768 0 0 15 0 8 1565108016 1 1 1 False
# Inserting Station: 3769 0 0 5 0 18 1565107925 1 1 1 False
# Inserting Station: 3770 0 0 17 0 4 1565102224 1 1 1 False
# Inserting Station: 3771 0 0 4 0 24 1565107275 1 1 1 False
# Inserting Station: 3772 0 0 15 0 4 1565108181 1 1 1 False
# Inserting Station: 3773 0 0 10 0 10 1565093744 1 1 1 False
# Inserting Station: 3774 0 0 14 0 9 1565095070 1 1 1 False
# Inserting Station: 3775 0 0 22 0 5 1565104427 1 1 1 False
# Inserting Station: 3776 0 0 23 0 0 1565105809 1 1 1 False
# Inserting Station: 3777 0 0 17 0 6 1565107999 1 1 1 False
# Inserting Station: 3778 0 0 26 0 1 1565105845 1 1 1 False
# Inserting Station: 3779 0 0 20 0 4 1565102243 1 1 1 False
# Inserting Station: 3781 0 0 14 2 14 1565107793 1 1 1 False
# Inserting Station: 3782 0 0 0 2 29 1565107252 1 1 1 True
# Inserting Station: 3783 0 0 10 0 27 1565107824 1 1 1 False
# Inserting Station: 3787 0 0 0 0 22 1565099396 1 1 1 False
# Inserting Station: 3788 0 0 13 1 13 1565108107 1 1 1 False
# Inserting Station: 3789 0 0 30 1 0 1565106988 1 1 1 False
# Inserting Station: 3790 0 0 14 1 22 1565107421 1 1 1 False
# Inserting Station: 3791 0 0 21 0 11 1565099862 1 1 1 False
# Inserting Station: 3792 0 0 3 1 25 1565107846 1 1 1 False
# Inserting Station: 3795 0 0 1 0 18 1565105000 1 1 1 False
# Inserting Station: 3798 0 0 23 1 31 1565107437 1 1 1 False
# Inserting Station: 3799 0 0 27 0 4 1565108116 1 1 1 False
# Inserting Station: 3803 0 0 19 0 4 1565107800 1 1 1 False

# %%
c = db.cursor() # set our cursor 

c.execute("SELECT * FROM StationInfo LIMIT 5;") # look at the first five entries 
rows = c.fetchall()

print(rows)

c.close()
db.commit()
# Out:
# ((168, 0, 0, 38, 1, 8, '1564509309', 0, 1, 1, 0), (281, 0, 1, 60, 1, 4, '1564509454', 0, 1, 1, 1), (285, 0, 0, 0, 0, 0, '18001', 0, 0, 1, 1), (304, 0, 0, 20, 1, 12, '1564509353', 0, 1, 1, 1), (337, 0, 0, 31, 1, 5, '1564509023', 0, 1, 1, 0))

# %% [markdown]
# ## Last but not least, let's set things up so that our database automatically updates every 15 seconds.

# %%
import time 
import json 
import urllib.request
from datetime import datetime

while True:
    
    with urllib.request.urlopen("https://gbfs.citibikenyc.com/gbfs/en/station_status.json") as url:
        data = json.loads(url.read().decode())

    stations = data['data']['stations'] # iterate through the json to find the station data

    db = MySQLdb.connect(passwd="password",db="citibike") # connect to our db

    c = db.cursor() # set our cursor

    query_template = """INSERT IGNORE INTO StationInfo(station_id, num_ebikes_available, num_docks_disabled, \
    num_docks_available, num_bikes_disabled, num_bikes_available, last_reported, is_returning, is_renting, \
    is_installed, eightd_has_available_keys) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);"""

    for entry in stations: # for every station entry in the json 
        station_id = int(entry['station_id']) # find and set station_id
        num_ebikes_available = int(entry['num_ebikes_available']) # find and set num_ebikes_available
        num_docks_disabled = int(entry['num_docks_disabled']) # find and set num_docks_disabled
        num_docks_available = int(entry['num_docks_available']) # find and set num_docks_available
        num_bikes_disabled = int(entry['num_bikes_disabled']) # find and set num_bikes_disabled
        num_bikes_available = int(entry['num_bikes_available']) # find and set num_bikes_available
        last_reported = str(entry['last_reported']) # find and set last_reported
        is_returning = int(entry['is_returning']) # find and set is_returning
        is_renting = int(entry['is_renting']) # find and set is_renting
        is_installed = int(entry['is_installed']) # find and set is_installed
        eightd_has_available_keys = bool(entry['eightd_has_available_keys']) # find and set eightd_has_available_keys

        c.execute(query_template, query_parameters) # execute insert query and parameters
        
    c.close()
    db.commit()
        
    c = db.cursor() # set our cursor

    c.execute("SELECT * FROM StationInfo LIMIT 5;") # look at the first five entries 
    rows = c.fetchall()

    print(rows)
        
    time.sleep(15)
# Out:
# ((168, 0, 0, 38, 1, 8, '1564509309', 0, 1, 1, 0), (281, 0, 1, 60, 1, 4, '1564509454', 0, 1, 1, 1), (285, 0, 0, 0, 0, 0, '18001', 0, 0, 1, 1), (304, 0, 0, 20, 1, 12, '1564509353', 0, 1, 1, 1), (337, 0, 0, 31, 1, 5, '1564509023', 0, 1, 1, 0))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-9a3ae6691221> in <module>
#      44     print(rows)
#      45
# ---> 46     time.sleep(15)
#      47
#
# KeyboardInterrupt:

# %% [markdown]
# ---

# %% [markdown]
# ## I hope this has helped you find your coding legs! Next week we'll get back to descriptive analytics using Python and Pandas. For now, take time to refresh yourself on the content covered in "Introduction to Programming".
#
# ## If you need a referesher on your SQL skills, check out the "Supplementary Info" directory in the class repo.
