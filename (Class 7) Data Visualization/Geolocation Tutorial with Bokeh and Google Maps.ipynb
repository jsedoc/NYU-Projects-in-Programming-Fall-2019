# %%
import pandas as pd

data = pd.read_csv("/Users/siegmanA/Desktop/NYU-Projects-in-Programming-Fall-2019/(Class 7) Data Visualization/NYPD_Crashes.csv",low_memory=False)

data.head()
# Out:
#          DATE   TIME BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/13/2019  10:00     NaN      NaN        NaN        NaN
# 1  02/06/2013  11:10     NaN      NaN        NaN        NaN
# 2  02/06/2013  12:29     NaN      NaN        NaN        NaN
# 3  02/06/2013  13:10     NaN      NaN  40.874499 -73.927609
# 4  09/13/2019  13:39     NaN      NaN        NaN        NaN
#
#                          LOCATION                    ON STREET NAME  \
# 0                             NaN  ELLINGTON PARKWAY
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3  POINT (-73.9276086 40.8744985)                               NaN
# 4                             NaN  QUEENSBORO BRIDGE UPPER ROADWAY
#
#   CROSS STREET NAME                           OFF STREET NAME  ...  \
# 0               NaN                                       NaN  ...
# 1               NaN                                       NaN  ...
# 2               NaN  PARKING LOT OF 70-11 PARSONS BOULEVARD    ...
# 3               NaN                                       NaN  ...
# 4               NaN                                       NaN  ...
#
#    CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0          Following Too Closely                            NaN
# 1                    Unspecified                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN                            NaN       4206265
# 1                            NaN                            NaN       2976030
# 2                            NaN                            NaN        234940
# 3                            NaN                            NaN       2874747
# 4                            NaN                            NaN       4205809
#
#              VEHICLE TYPE CODE 1            VEHICLE TYPE CODE 2  \
# 0                          Sedan                          Sedan
# 1                          OTHER  SPORT UTILITY / STATION WAGON
# 2  SPORT UTILITY / STATION WAGON                            NaN
# 3  SPORT UTILITY / STATION WAGON                            NaN
# 4                      Box Truck                            NaN
#
#    VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
data.dropna(subset=["LATITUDE","LONGITUDE"],inplace=True)

data.head()
# Out:
#           DATE   TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 3   02/06/2013  13:10       NaN      NaN  40.874499 -73.927609
# 8   09/13/2019  21:15  BROOKLYN    11215  40.671160 -73.971420
# 17  02/05/2013  12:30       NaN      NaN  40.697735 -73.814079
# 18  02/05/2013  18:10       NaN      NaN  40.606328 -74.079930
# 19  02/05/2013  18:40       NaN      NaN  40.584775 -73.960108
#
#                           LOCATION ON STREET NAME CROSS STREET NAME  \
# 3   POINT (-73.9276086 40.8744985)            NaN               NaN
# 8       POINT (-73.97142 40.67116)            NaN               NaN
# 17  POINT (-73.8140794 40.6977347)            NaN               NaN
# 18  POINT (-74.0799299 40.6063283)            NaN               NaN
# 19  POINT (-73.9601076 40.5847755)            NaN               NaN
#
#                              OFF STREET NAME  ...  \
# 3                                        NaN  ...
# 8   18        PROSPECT PARK WEST              ...
# 17                                       NaN  ...
# 18                                       NaN  ...
# 19                                       NaN  ...
#
#     CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 3                             NaN                            NaN
# 8                             NaN                            NaN
# 17                    Unspecified                            NaN
# 18                    Unspecified                            NaN
# 19                            NaN                            NaN
#
#     CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 3                             NaN                            NaN
# 8                             NaN                            NaN
# 17                            NaN                            NaN
# 18                            NaN                            NaN
# 19                            NaN                            NaN
#
#     COLLISION_ID            VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  \
# 3        2874747  SPORT UTILITY / STATION WAGON                  NaN
# 8        4206285                          Sedan                  NaN
# 17       2997767              PASSENGER VEHICLE    PASSENGER VEHICLE
# 18       3122183              PASSENGER VEHICLE    PASSENGER VEHICLE
# 19       2940781              PASSENGER VEHICLE                  NaN
#
#     VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 3                   NaN                 NaN                 NaN
# 8                   NaN                 NaN                 NaN
# 17                  NaN                 NaN                 NaN
# 18                  NaN                 NaN                 NaN
# 19                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
lat_long = data[["LATITUDE","LONGITUDE","DATE","TIME","BOROUGH","VEHICLE TYPE CODE 1"]]

# %%
lat_long.head()
# Out:
#      LATITUDE  LONGITUDE        DATE   TIME   BOROUGH  \
# 3   40.874499 -73.927609  02/06/2013  13:10       NaN
# 8   40.671160 -73.971420  09/13/2019  21:15  BROOKLYN
# 17  40.697735 -73.814079  02/05/2013  12:30       NaN
# 18  40.606328 -74.079930  02/05/2013  18:10       NaN
# 19  40.584775 -73.960108  02/05/2013  18:40       NaN
#
#               VEHICLE TYPE CODE 1
# 3   SPORT UTILITY / STATION WAGON
# 8                           Sedan
# 17              PASSENGER VEHICLE
# 18              PASSENGER VEHICLE
# 19              PASSENGER VEHICLE

# %%
test = lat_long[:100]

# %%
test
# Out:
#       LATITUDE  LONGITUDE        DATE   TIME    BOROUGH  \
# 3    40.874499 -73.927609  02/06/2013  13:10        NaN
# 8    40.671160 -73.971420  09/13/2019  21:15   BROOKLYN
# 17   40.697735 -73.814079  02/05/2013  12:30        NaN
# 18   40.606328 -74.079930  02/05/2013  18:10        NaN
# 19   40.584775 -73.960108  02/05/2013  18:40        NaN
# 23   40.736353 -73.975009  02/04/2013  11:10        NaN
# 25   40.745823 -73.772420  09/11/2019  15:30        NaN
# 26   40.700939 -73.806046  02/04/2013  15:00     QUEENS
# 29   40.734982 -73.861387  02/04/2013  19:00        NaN
# 31   40.701651 -73.991484  02/04/2013   4:00        NaN
# 33   40.789386 -73.782317  02/04/2013   8:20        NaN
# 35   40.757072 -73.969860  09/10/2019  14:10        NaN
# 41   40.699955 -73.986820  09/10/2019   6:16        NaN
# 47   40.764320 -73.977200  09/09/2019  14:50  MANHATTAN
# 48   40.607780 -74.137011  02/02/2013  18:35        NaN
# 49   40.713203 -73.977219  02/02/2013  20:55        NaN
# 55   40.747092 -73.763239  02/01/2013  11:58        NaN
# 62   40.768742 -73.908804  02/01/2013   4:30        NaN
# 63   40.751082 -73.749144  02/01/2013   8:00        NaN
# 65   40.749478 -73.718444  02/01/2013   9:33     QUEENS
# 79   40.797000 -73.937780  09/06/2019  15:05  MANHATTAN
# 81   40.754553 -73.743165  01/30/2013  11:15        NaN
# 87   40.743011 -73.777566  01/30/2013   7:51        NaN
# 92   40.842148 -73.900826  09/05/2019   7:45      BRONX
# 93   40.772966 -73.958256  01/29/2013  18:31  MANHATTAN
# 96   40.702957 -73.902390  09/04/2019   0:48     QUEENS
# 98   40.698120 -73.995460  09/04/2019  11:48        NaN
# 101  40.708980 -73.804180  09/04/2019  13:20     QUEENS
# 102  40.748470 -73.870026  09/04/2019  15:12     QUEENS
# 109  40.584888 -73.928840  01/28/2013  18:35        NaN
# ..         ...        ...         ...    ...        ...
# 282  40.883872 -73.886946  01/11/2013  15:00        NaN
# 289  40.703434 -73.740502  01/11/2013  19:30     QUEENS
# 295  40.737210 -73.863930  08/17/2019  14:00     QUEENS
# 297  40.801125 -73.929880  08/17/2019  17:37        NaN
# 299  40.824295 -73.825584  08/17/2019  19:40      BRONX
# 303  40.759933 -73.986350  08/16/2019  11:30  MANHATTAN
# 307  40.879055 -73.874390  08/16/2019   1:00        NaN
# 309  40.583201 -73.973027  01/09/2013  15:00        NaN
# 312  40.708767 -73.998108  01/09/2013  17:10        NaN
# 313  40.740550 -73.788105  01/09/2013  19:00        NaN
# 314  40.681637 -73.993920  08/15/2019  12:40        NaN
# 315  40.799976 -73.958626  08/15/2019  14:10        NaN
# 319  40.809864 -73.946434  08/15/2019  17:09  MANHATTAN
# 320  40.727663 -73.929374  01/08/2013  10:45        NaN
# 322  40.526894 -74.167280  08/15/2019  19:45        NaN
# 324  40.695770 -73.747460  08/15/2019  20:28        NaN
# 326  40.845190 -73.911200  08/15/2019   9:30        NaN
# 329  40.722984 -73.951360  08/14/2019  11:55   BROOKLYN
# 333  40.666502 -73.996189  01/07/2013   0:15        NaN
# 334  40.864403 -73.923775  08/14/2019  16:26        NaN
# 335  40.734882 -73.974840  08/14/2019  17:40        NaN
# 341  40.596511 -73.907876  01/14/2013  18:18   BROOKLYN
# 343  40.831140 -73.879776  08/13/2019  15:42      BRONX
# 345  40.734251 -73.863351  01/06/2013  12:26        NaN
# 349  40.651104 -73.943810  08/12/2019  14:45   BROOKLYN
# 352  40.657020 -74.004731  01/10/2013   7:57        NaN
# 364  40.771122 -73.869635  01/04/2013   5:30        NaN
# 368  40.781667 -73.986689  01/03/2013  18:30        NaN
# 369  40.816883 -73.962650  08/10/2019   3:40        NaN
# 370  40.610745 -74.095829  01/03/2013  22:10        NaN
#
#                      VEHICLE TYPE CODE 1
# 3          SPORT UTILITY / STATION WAGON
# 8                                  Sedan
# 17                     PASSENGER VEHICLE
# 18                     PASSENGER VEHICLE
# 19                     PASSENGER VEHICLE
# 23         SPORT UTILITY / STATION WAGON
# 25                                 Sedan
# 26                     PASSENGER VEHICLE
# 29         SPORT UTILITY / STATION WAGON
# 31        LARGE COM VEH(6 OR MORE TIRES)
# 33         SPORT UTILITY / STATION WAGON
# 35   Station Wagon/Sport Utility Vehicle
# 41                                 Sedan
# 47                                 Sedan
# 48                     PASSENGER VEHICLE
# 49                     PASSENGER VEHICLE
# 55                                 OTHER
# 62         SPORT UTILITY / STATION WAGON
# 63        LARGE COM VEH(6 OR MORE TIRES)
# 65                     PASSENGER VEHICLE
# 79                                  Bike
# 81                     PASSENGER VEHICLE
# 87                     PASSENGER VEHICLE
# 92                                   NaN
# 93                     PASSENGER VEHICLE
# 96                                 Sedan
# 98                                   Van
# 101                                  NaN
# 102                                 Bike
# 109                    PASSENGER VEHICLE
# ..                                   ...
# 282                    PASSENGER VEHICLE
# 289                    PASSENGER VEHICLE
# 295                                Sedan
# 297                                Sedan
# 299                                Sedan
# 303                                Sedan
# 307                                 Bike
# 309                    PASSENGER VEHICLE
# 312                    PASSENGER VEHICLE
# 313                    PASSENGER VEHICLE
# 314                                Sedan
# 315                                Sedan
# 319                                Sedan
# 320                    PASSENGER VEHICLE
# 322                                Sedan
# 324  Station Wagon/Sport Utility Vehicle
# 326                                Sedan
# 329                                DELIV
# 333                    PASSENGER VEHICLE
# 334                                Sedan
# 335                                Sedan
# 341                    PASSENGER VEHICLE
# 343                                Sedan
# 345        SPORT UTILITY / STATION WAGON
# 349                                 Bike
# 352                    PASSENGER VEHICLE
# 364                    PASSENGER VEHICLE
# 368                    PASSENGER VEHICLE
# 369                                Sedan
# 370                    PASSENGER VEHICLE
#
# [100 rows x 6 columns]

# %%
lat_list = list(test['LATITUDE'])
lon_list = list(test['LONGITUDE'])

date_list = list(test['DATE'])
time_list = list(test['TIME'])
borough_list = list(test['BOROUGH'])
vehicle_list = list(test['VEHICLE TYPE CODE 1'])

# %% [markdown]
# ---

# %%
# https://docs.bokeh.org/en/latest/

from bokeh.io import output_file, show 
from bokeh.models import *


map_options = GMapOptions(lat=40.7128, lng=-74.0060, map_type="roadmap", zoom=11)

plot = GMapPlot(x_range=Range1d(), y_range=Range1d(), map_options=map_options,api_key = "AIzaSyDl5U_JnDTgIVMftrDtXhSSW-ImtObs1AA")

source = ColumnDataSource(
    data = dict(
        lat=lat_list,
        lon=lon_list,
        date = date_list,
        time = time_list,
        borough = borough_list, 
        vehicle = vehicle_list
    ))

circle = Circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool(), BoxZoomTool())

plot.title.text="NYC Accidents"

plot.add_tools(HoverTool(
    tooltips=[
        ( 'date',   '@date' ),
        ( 'time',  '@time' ), 
        ( 'borough', '@borough' ), 
        ( 'vehicle', '@vehicle' )
    ],

    formatters={
        'date' : 'datetime', # use 'datetime' formatter for 'date' field
        'time' : 'printf',
        'borough' : 'numeral',
        'vehicle' : 'numeral'
    },

    mode='vline'
))

# output_file("gmap_plot.html")

show(plot)
# Out:
#   <div class="bk-root" id="80387c07-3e20-4eb4-ad58-5c4af604cd9c" data-root-id="9655"></div>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---
